# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
df = pd.read_csv(r'/Users/bird/Downloads/MovieIndustry.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# check for missing data (using loop)

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing data type -- The capital “I” (Int64) allows NaNs!

df['budget'] = df['budget'].astype('Int64')
df['gross'] = df['gross'].astype('Int64')
df['votes'] = df['votes'].astype('Int64')
df['runtime'] = df['runtime'].astype('Int64')
df['name'] = df['name'].astype('str')

# %%
# take the first four values and make that the new column
#\d{4} → matches any 4-digit number.
#str.extract() → returns the first match per string.

df['yearcorrect']= df['released'].astype(str).str.extract(r'(\d{4})')

# %%
# Giving table order
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score    votes       director  \
# ...

# %%
df.duplicated().any()
# check entire data frame for duplicates
# Out:
# np.False_

# %%
# scatter plot to compare

plt.title('Budget vs Gross')

plt.xlabel('Gross Earnings')
plt.ylabel('Film Budget')

plt.scatter(x=df['budget'], y=df['gross'])

# %%
# create regression plot

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'orange'}, line_kws={'color': 'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# looking at correlation
# numeric_only=True automatically ignores non-numeric columns
# corr() works only on numeric fields (so no strings)
#diff types of corr(methods='pearson') : pearson (default), kendall, spearmen

df.corr(numeric_only=True) #this gives us the correlation matrix
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
# visual correlation matrix
correlation_matrix = df.corr(numeric_only=True)

plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

sns.heatmap(correlation_matrix, annot=True)

plt.show()

# %%
# looks at company -- not numeric but we can convert a numeric representation

df_numvert = df

for col_name in df_numvert.columns:
    if(df_numvert[col_name].dtype == 'object'):
        df_numvert[col_name] = df_numvert[col_name].astype('category')
        df_numvert[col_name] = df_numvert[col_name].cat.codes

df_numvert
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000      1111    2567
# 3      286       4      4  1980      1492    7.7   221000      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000      1054     521
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36       774    2614
# 7665  4717      -1      6  2020       193    5.7       29      2061    2683
# 7666  2843      -1      6  2020      2817    NaN     <NA>      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7      2165    3344
#
# ...

# %%
correlation_matrix = df_numvert.corr()

plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

sns.heatmap(correlation_matrix, annot=True)

plt.show()

# %%
# using unstacking

correlation_matrix = df_numvert.corr()
corr_pairs = correlation_matrix.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#                               ...
# yearcorrect  budget         0.321918
#              gross          0.250514
#              company       -0.014144
#              runtime        0.120636
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
# pairing the unstacks together

sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.356564
# budget       genre         -0.356564
# genre        gross         -0.235650
# gross        genre         -0.235650
# rating       budget        -0.176002
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# votes        gross          0.630757
# gross        votes          0.630757
#              budget         0.740395
# budget       gross          0.740395
# yearcorrect  year           0.996397
# year         yearcorrect    0.996397
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# company has low correlation
